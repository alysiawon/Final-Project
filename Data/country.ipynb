# %%
# Import Dependencies
import pandas as pd
import os as os

# %% [markdown]
# ### GDP

# %%
# Open GDP Data File
gdp_file_to_load = os.path.join("Resources","World GDP", "gdp_data.csv")
gdp_df = pd.read_csv(gdp_file_to_load)
gdp_df
# Out:
#             Country Code  Year  GDP-Growth  GDP-Per-Capita           GDP
# 0             Aruba  ABW  1960         NaN             NaN           NaN
# 1       Afghanistan  AFG  1960         NaN             NaN           NaN
# 2            Angola  AGO  1960         NaN             NaN           NaN
# 3           Albania  ALB  1960         NaN             NaN           NaN
# 4           Andorra  AND  1960         NaN             NaN           NaN
# ...             ...  ...   ...         ...             ...           ...
# 15043        Kosovo  XKX  2016    4.145372     4193.631327  7.738508e+09
# 15044   Yemen, Rep.  YEM  2016   -2.701475      667.945437  1.903557e+10
# 15045  South Africa  ZAF  2016    0.787056     7439.919412  4.298757e+11
# 15046        Zambia  ZMB  2016    3.794901     1672.345428  2.901824e+10
# 15047      Zimbabwe  ZWE  2016    6.159190     1322.344063  1.909335e+10
#
# [15048 rows x 6 columns]

# %%
# Drop Columns
gdp_df.drop(["GDP-Growth","GDP-Per-Capita"], axis=1, inplace=True)

# Rearrange Columns
gdp_df.reindex(['Year', 'Country','Code','GDP'], axis=1)
# Out:
#        Year       Country Code           GDP
# 0      1960         Aruba  ABW           NaN
# 1      1960   Afghanistan  AFG           NaN
# 2      1960        Angola  AGO           NaN
# 3      1960       Albania  ALB           NaN
# 4      1960       Andorra  AND           NaN
# ...     ...           ...  ...           ...
# 15043  2016        Kosovo  XKX  7.738508e+09
# 15044  2016   Yemen, Rep.  YEM  1.903557e+10
# 15045  2016  South Africa  ZAF  4.298757e+11
# 15046  2016        Zambia  ZMB  2.901824e+10
# 15047  2016      Zimbabwe  ZWE  1.909335e+10
#
# [15048 rows x 4 columns]

# %% [markdown]
# ### Population

# %%
# Open Population Data File
population_file_to_load = os.path.join("Resources","World Population", "population.csv")
population_df = pd.read_csv(population_file_to_load)
population_df
# Out:
#       Year   Country  Population  Yearly % Change  Yearly Change  \
# 0     2020     China  1439323776             0.39        5540090
# 1     2019     China  1433783686             0.43        6135900
# 2     2018     China  1427647786             0.47        6625995
# 3     2017     China  1421021791             0.49        6972440
# 4     2016     China  1414049351             0.51        7201481
# ...    ...       ...         ...              ...            ...
# 4190  1975  Holy See         728             2.48             17
# 4191  1970  Holy See         644            -5.49            -42
# 4192  1965  Holy See         854            -1.18            -10
# 4193  1960  Holy See         906            -0.04              0
# 4194  1955  Holy See         908             0.00              0
#
#       Migrants (net)  Median Age  Fertility Rate Density (P/Km²)  Urban Pop %  \
# 0          -348399.0        38.4            1.69             153         60.8
# ...

# %%
# Drop Columns
population_df.drop(["Yearly % Change", "Yearly Change", "Migrants (net)", "Median Age", 
                    "Fertility Rate","Density (P/Km²)","Urban Pop %","Urban Population", 
                    "Country's Share of World Pop %", "Country Global Rank", "World Population"], axis=1, inplace=True)
population_df.head()
# Out:
#    Year Country  Population
# 0  2020   China  1439323776
# 1  2019   China  1433783686
# 2  2018   China  1427647786
# 3  2017   China  1421021791
# 4  2016   China  1414049351

# %% [markdown]
# ### Merge Dataframe

# %%
# Merge Dataframe
country_df = pd.merge(gdp_df, population_df, on=['Year','Country'])
country_df.head()
# Out:
#        Country Code  Year  GDP  Population
# 0        Aruba  ABW  1960  NaN       54211
# 1  Afghanistan  AFG  1960  NaN     8996973
# 2       Angola  AGO  1960  NaN     5454933
# 3      Albania  ALB  1960  NaN     1636090
# 4      Andorra  AND  1960  NaN       13411

# %%
# Export CSV
country_df.to_csv('Data/country.csv', index=False)
