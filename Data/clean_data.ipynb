# %%
# Import Dependencies
import pandas as pd
import os as os

# %% [markdown]
# ## 120 Years of Olympic Data

# %%
# Open 120 Years of Olympic Data File
olympic_athletes_file_to_load = os.path.join("Resources","120 Years Of Olympic Data", "athlete_events.csv")
olympic_athletes_df = pd.read_csv(olympic_athletes_file_to_load)
olympic_athletes_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
# Remove Bronze & Silver
gold_olympic_athletes_df = olympic_athletes_df[olympic_athletes_df.Medal == "Gold"]
gold_olympic_athletes_df.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight            Team  \
# 3    4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#     NOC        Games  Year  Season         City          Sport  \
# 3   DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 42  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 44  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 48  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 60  NOR  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                                Event Medal
# 3        Tug-Of-War Men's Tug-Of-War  Gold
# 42  Gymnastics Men's Team All-Around  Gold
# ...

# %%
# Drop Columns
gold_olympic_athletes_df.drop(["ID","Team","Games","Season","City"], axis=1, inplace=True)
gold_olympic_athletes_df.head()
# Out:
# /Users/alysiawon/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                        Name Sex   Age  Height  Weight  NOC  Year  \
# 3      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN  1900
# 42  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  FIN  1948
# 44  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  FIN  1948
# 48  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  FIN  1948
# 60       Kjetil Andr Aamodt   M  20.0   176.0    85.0  NOR  1992
#
#             Sport                             Event Medal
# 3      Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 42     Gymnastics  Gymnastics Men's Team All-Around  Gold
# ...

# %% [markdown]
# ### 2020 Olympics Data

# %%
# Open 2020 Olympic Athlete Data File
current_olympic_athletes_file_to_load = os.path.join("Resources","2021 Olympics", "athletes.csv")
current_olympic_athletes_df = pd.read_csv(current_olympic_athletes_file_to_load)
current_olympic_athletes_df.head()
# Out:
#                 name  short_name  gender  birth_date birth_place  \
# 0    AALERUD Katrine   AALERUD K  Female  1994-12-04      VESTBY
# 1        ABAD Nestor      ABAD N    Male  1993-03-29       ALCOI
# 2  ABAGNALE Giovanni  ABAGNALE G    Male  1995-01-11    GRAGNANO
# 3     ABALDE Alberto    ABALDE A    Male  1995-12-15      FERROL
# 4      ABALDE Tamara    ABALDE T  Female  1989-02-06        VIGO
#
#   birth_country country country_code           discipline discipline_code  \
# 0        Norway  Norway          NOR         Cycling Road             CRD
# 1         Spain   Spain          ESP  Artistic Gymnastics             GAR
# 2         Italy   Italy          ITA               Rowing             ROW
# 3         Spain   Spain          ESP           Basketball             BKB
# 4         Spain   Spain          ESP           Basketball             BKB
#
#   residence_place residence_country height_m/ft  \
# 0             NaN               NaN         NaN
# ...

# %%
# Drop Columns
current_olympic_athletes_df.drop(["short_name","birth_place","birth_country","residence_place","residence_country","url"], axis=1, inplace=True)
current_olympic_athletes_df.head()
# Out:
#                 name  gender  birth_date country country_code  \
# 0    AALERUD Katrine  Female  1994-12-04  Norway          NOR
# 1        ABAD Nestor    Male  1993-03-29   Spain          ESP
# 2  ABAGNALE Giovanni    Male  1995-01-11   Italy          ITA
# 3     ABALDE Alberto    Male  1995-12-15   Spain          ESP
# 4      ABALDE Tamara  Female  1989-02-06   Spain          ESP
#
#             discipline discipline_code height_m/ft
# 0         Cycling Road             CRD         NaN
# 1  Artistic Gymnastics             GAR  1.65/5'4''
# 2               Rowing             ROW  1.98/6'5''
# 3           Basketball             BKB  2.00/6'6''
# 4           Basketball             BKB  1.92/6'3''

# %%
# Open 2020 Olympic Medal Data File
current_olympic_medals_file_to_load = os.path.join("Resources","2021 Olympics", "medals.csv")
current_olympic_medals_df = pd.read_csv(current_olympic_medals_file_to_load)
current_olympic_medals_df.head()
# Out:
#      medal_type  medal_code             medal_date athlete_short_name  \
# 0    Gold Medal           1  2021-07-24 00:00:00.0             KIM JD
# 1    Gold Medal           1  2021-07-24 00:00:00.0               AN S
# 2  Silver Medal           2  2021-07-24 00:00:00.0       SCHLOESSER G
# 3  Silver Medal           2  2021-07-24 00:00:00.0           WIJLER S
# 4  Bronze Medal           3  2021-07-24 00:00:00.0          ALVAREZ L
#
#           athlete_name athlete_sex  \
# 0          KIM Je Deok           X
# 1               AN San           X
# 2  SCHLOESSER Gabriela           X
# 3         WIJLER Steve           X
# 4         ALVAREZ Luis           X
#
#                                         athlete_link country_code  \
# 0  ../../../en/results/archery/athlete-profile-n1...          KOR
# 1  ../../../en/results/archery/athlete-profile-n1...          KOR
# 2  ../../../en/results/archery/athlete-profile-n1...          NED
# ...

# %%
# Remove Bronze & Silver
gold_current_olympic_athletes_df = current_olympic_medals_df[current_olympic_medals_df.medal_type == "Gold Medal"]
gold_current_olympic_athletes_df.head()
# Out:
#     medal_type  medal_code             medal_date athlete_short_name  \
# 0   Gold Medal           1  2021-07-24 00:00:00.0             KIM JD
# 1   Gold Medal           1  2021-07-24 00:00:00.0               AN S
# 6   Gold Medal           1  2021-07-24 00:00:00.0          CARAPAZ R
# 9   Gold Medal           1  2021-07-24 00:00:00.0         SZILAGYI A
# 12  Gold Medal           1  2021-07-24 00:00:00.0              SUN Y
#
#        athlete_name athlete_sex  \
# 0       KIM Je Deok           X
# 1            AN San           X
# 6   CARAPAZ Richard           M
# 9     SZILAGYI Aron           M
# 12        SUN Yiwen           W
#
#                                          athlete_link country_code  \
# 0   ../../../en/results/archery/athlete-profile-n1...          KOR
# 1   ../../../en/results/archery/athlete-profile-n1...          KOR
# 6   ../../../en/results/cycling-road/athlete-profi...          ECU
# 9   ../../../en/results/fencing/athlete-profile-n1...          HUN
# ...

# %%
# Drop Columns
gold_current_olympic_athletes_df.drop(["medal_code","medal_date","athlete_short_name","athlete_link"], axis=1, inplace=True)
gold_current_olympic_athletes_df.head()
# Out:
# /Users/alysiawon/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#     medal_type     athlete_name athlete_sex country_code discipline_code  \
# 0   Gold Medal      KIM Je Deok           X          KOR             ARC
# 1   Gold Medal           AN San           X          KOR             ARC
# 6   Gold Medal  CARAPAZ Richard           M          ECU             CRD
# 9   Gold Medal    SZILAGYI Aron           M          HUN             FEN
# 12  Gold Medal        SUN Yiwen           W          CHN             FEN
#
#                                     event                     country  \
# 0                              Mixed Team           Republic of Korea
# ...
